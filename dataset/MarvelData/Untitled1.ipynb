# %%
import pandas as pd
data = pd.read_csv("names_message.csv",header=None,names=['name','id'])
data
# Out:
#          name   id
# 0       tonys    1
# 1       rhody    2
# 2       hawke    3
# 3      stever    4
# 4      falcon    5
# ..        ...  ...
# 177  outrider  178
# 178     ironl  179
# 179  jacksonn  180
# 180    jarvis  181
# 181   stanlee  182
#
# [182 rows x 2 columns]

# %%
message = pd.read_csv("message.csv",header=None,names=['name','fullname','isalive','group'])
message.values
# Out:
# array([['tonys', 'Tony Stark', 'alive', 'human'],
#        ['stever', 'Steve Rogers', 'alive', 'human'],
#        ['bruceb', 'Bruce Banner', 'alive', 'human'],
#        ['thor', 'Thor', 'alive', 'asgardian'],
#        ['blackw', 'Natasha Romanoff', 'alive', 'human'],
#        ['rhody', 'James Rhodes', 'alive', 'human'],
#        ['hawke', 'Clint Barton', 'alive', 'human'],
#        ['nickf', 'Nick Fury', 'alive', 'human'],
#        ['falcon', 'Sam Wilson', 'alive', 'human'],
#        ['vision', 'Vision', 'alive', 'machine'],
#        ['wandam', 'Wanda Maximoff', 'alive', 'human'],
#        ['pietrom', 'Pietro Maxiomoff', 'deceased', 'human'],
#        ['ultronu', 'Ultimate Ultron', 'deceased', 'machine'],
#        ['helenc', 'Helen Cho', 'alive', 'human'],
#        ['ultrons', 'Ultron Sentry', 'deceased', 'machine'],
#        ['mariah', 'Maria Hill', 'alive', 'human'],
#        ['wolfgangv', 'Wolfgang von Strucker', 'deceased', 'human'],
# ...
